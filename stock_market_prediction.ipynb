# %%
#import require labraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Pandas is a Python library used for working with data sets. It has functions for analyzing, cleaning, exploring, and manipulating data
#
# NumPy is a Python library used for working with arrays. It also has functions for working in the domain of linear algebra, Fourier transform, and matrices

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\sanjana\anaconda3\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\sanjana\anaconda3\lib\site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\sanjana\anaconda3\lib\site-packages (from pmdarima) (3.0.7)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\sanjana\anaconda3\lib\site-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: pandas>=0.19 in c:\users\sanjana\anaconda3\lib\site-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\sanjana\anaconda3\lib\site-packages (from pmdarima) (1.3.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\sanjana\anaconda3\lib\site-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\sanjana\anaconda3\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in c:\users\sanjana\anaconda3\lib\site-packages (from pmdarima) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\sanjana\anaconda3\lib\site-packages (from pmdarima) (68.0.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\sanjana\anaconda3\lib\site-packages (from pmdarima) (23.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sanjana\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sanjana\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sanjana\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\sanjana\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in c:\users\sanjana\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv(r"C:\Users\Sanjana\Desktop\machine learning\shiash project\HCLTECH.csv")
df.head()
# Out:
#          Date   Symbol Series  Prev Close    Open     High      Low     Last  \
# 0  2000-01-11  HCLTECH     EQ      580.00  1550.0  1725.00  1492.00  1560.00
# 1  2000-01-12  HCLTECH     EQ     1554.45  1560.0  1678.85  1560.00  1678.85
# 2  2000-01-13  HCLTECH     EQ     1678.85  1790.0  1813.20  1781.00  1813.20
# 3  2000-01-14  HCLTECH     EQ     1813.20  1958.3  1958.30  1835.00  1958.30
# 4  2000-01-17  HCLTECH     EQ     1958.30  2115.0  2115.00  1801.65  1801.65
#
#      Close     VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  1554.45  1582.72  1192200  1.886915e+14     NaN                 NaN
# 1  1678.85  1657.05   344850  5.714349e+13     NaN                 NaN
# 2  1813.20  1804.69    53000  9.564880e+12     NaN                 NaN
# 3  1958.30  1939.90   270950  5.256169e+13     NaN                 NaN
# 4  1801.65  1990.55   428800  8.535473e+13     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
df.shape
# Out:
# (5300, 15)

# %%
df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5300.000000  5300.000000  5300.000000  5300.000000  5300.000000
# mean    642.113802   643.018887   654.269217   630.466274   642.240547
# std     411.660337   413.208429   420.237830   404.336086   411.739377
# min      89.700000    87.100000    94.750000    86.650000    89.000000
# 25%     314.200000   315.825000   322.725000   308.050000   314.462500
# 50%     535.075000   533.250000   545.000000   520.250000   535.150000
# 75%     893.975000   893.425000   907.837500   882.487500   895.425000
# max    2819.150000  2825.000000  2998.000000  2760.500000  2805.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  5300.000000  5300.000000  5.300000e+03  5.300000e+03    2456.000000
# mean    642.173981   642.502587  1.645121e+06  1.075213e+14   65378.973941
# std     411.674568   412.001186  2.187826e+06  1.718074e+14   47842.804142
# min      89.700000    91.440000  8.500000e+02  5.092228e+10     482.000000
# 25%     314.200000   315.047500  5.917092e+05  2.166692e+13   35885.750000
# 50%     535.075000   533.600000  1.036871e+06  4.816815e+13   55244.500000
# 75%     894.387500   895.102500  1.775460e+06  1.313830e+14   81039.000000
# max    2819.150000  2883.950000  3.231253e+07  2.532038e+15  465056.000000
#
#        Deliverable Volume  %Deliverble
# count        4.797000e+03  4797.000000
# mean         8.142533e+05     0.504206
# std          9.392883e+05     0.177111
# min          3.095000e+03     0.045600
# 25%          2.671450e+05     0.380000
# 50%          5.379440e+05     0.528600
# 75%          9.818800e+05     0.636100
# max          1.973903e+07     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5300 entries, 0 to 5299
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5300 non-null   object
#  1   Symbol              5300 non-null   object
#  2   Series              5300 non-null   object
#  3   Prev Close          5300 non-null   float64
#  4   Open                5300 non-null   float64
#  5   High                5300 non-null   float64
#  6   Low                 5300 non-null   float64
#  7   Last                5300 non-null   float64
#  8   Close               5300 non-null   float64
#  9   VWAP                5300 non-null   float64
#  10  Volume              5300 non-null   int64
#  11  Turnover            5300 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4797 non-null   float64
#  14  %Deliverble         4797 non-null   float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 621.2+ KB

# %%
hcl=df.dropna()

# %%
hcl.isnull().sum()
# Out:
# Date                  0
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
hcl.index=pd.to_datetime(hcl.Date)

# %%
hcl
# Out:
#                   Date   Symbol Series  Prev Close    Open    High     Low  \
# Date
# 2011-06-01  2011-06-01  HCLTECH     EQ      514.80  511.40  516.00  509.00
# 2011-06-02  2011-06-02  HCLTECH     EQ      514.40  509.00  515.25  508.70
# 2011-06-03  2011-06-03  HCLTECH     EQ      513.70  512.05  517.50  508.90
# 2011-06-06  2011-06-06  HCLTECH     EQ      512.35  508.05  514.00  505.05
# 2011-06-07  2011-06-07  HCLTECH     EQ      509.50  504.05  514.95  504.05
# ...                ...      ...    ...         ...     ...     ...     ...
# 2021-04-26  2021-04-26  HCLTECH     EQ      955.65  940.00  954.50  923.05
# 2021-04-27  2021-04-27  HCLTECH     EQ      928.80  931.00  938.55  923.40
# 2021-04-28  2021-04-28  HCLTECH     EQ      928.85  931.20  935.85  921.75
# 2021-04-29  2021-04-29  HCLTECH     EQ      923.80  929.70  929.70  907.10
# 2021-04-30  2021-04-30  HCLTECH     EQ      909.55  905.00  915.00  895.40
#
#               Last   Close    VWAP    Volume      Turnover    Trades  \
# Date
# 2011-06-01  514.75  514.40  512.70    287699  1.475043e+13    4845.0
# 2011-06-02  514.75  513.70  512.86    307689  1.578028e+13    6701.0
# 2011-06-03  513.70  512.35  513.58    379167  1.947326e+13    9447.0
# 2011-06-06  509.10  509.50  508.07    285294  1.449495e+13    5368.0
# 2011-06-07  511.95  511.80  510.77    403694  2.061968e+13    8530.0
# ...            ...     ...     ...       ...           ...       ...
# 2021-04-26  930.00  928.80  931.70  19619972  1.827997e+15  311431.0
# 2021-04-27  930.30  928.85  928.06   6406825  5.945938e+14  180458.0
# 2021-04-28  925.90  923.80  926.63   6845677  6.343403e+14  228230.0
# 2021-04-29  910.30  909.55  914.34   8588734  7.852988e+14  363122.0
# 2021-04-30  900.10  898.95  904.98  10921664  9.883911e+14  465056.0
#
#             Deliverable Volume  %Deliverble
# Date
# 2011-06-01            146731.0       0.5100
# 2011-06-02            144265.0       0.4689
# 2011-06-03            143384.0       0.3782
# 2011-06-06            100251.0       0.3514
# 2011-06-07            262636.0       0.6506
# ...                        ...          ...
# 2021-04-26           9218485.0       0.4699
# 2021-04-27           3233276.0       0.5047
# 2021-04-28           3890178.0       0.5683
# 2021-04-29           4041614.0       0.4706
# 2021-04-30           6189272.0       0.5667
#
# [2456 rows x 15 columns]

# %%
hcl.shape
# Out:
# (2456, 15)

# %%
hcl.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
hcl=hcl['Prev Close']['2013-01-01':'2013-12-02']
hcl
# Out:
# Date
# 2013-01-01     618.70
# 2013-01-02     622.15
# 2013-01-03     625.25
# 2013-01-04     625.95
# 2013-01-07     634.05
#                ...
# 2013-11-26    1053.00
# 2013-11-27    1059.75
# 2013-11-28    1058.55
# 2013-11-29    1062.15
# 2013-12-02    1086.00
# Name: Prev Close, Length: 230, dtype: float64

# %%
sns.countplot(data=df,x="Symbol")
# Out:
# <Axes: xlabel='Symbol', ylabel='count'>

# %%
sns.distplot(a=df["Prev Close"])
# Out:
# <Axes: xlabel='Prev Close', ylabel='Density'>

# %%
sns.distplot(a=df["Open"])
# Out:
# <Axes: xlabel='Open', ylabel='Density'>

# %%
sns.distplot(a=df["Volume"])
# Out:
# <Axes: xlabel='Volume', ylabel='Density'>

# %%
sns.distplot(a=df["Turnover"])
# Out:
# <Axes: xlabel='Turnover', ylabel='Density'>

# %%
sns.heatmap(df.corr(),annot=True,cmap="viridis_r",linewidth=2,linecolor="k")
# Out:
# <Axes: >

# %%
plt.plot(hcl)
plt.xlabel("Time frame")
plt.ylabel("stock market of hcl")
plt.show()

# %%
#here we are applying log function
st_log=np.log(hcl)
#it cal the log of an array hcl
plt.plot(st_log)

# %%
#differnating the log function
plt.figure(figsize=(15,15))
st_log_diff=st_log-st_log.shift()
#the logarithm of the stock and the logarithm of the previous day’s stock 
plt.plot(st_log_diff)

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
model=ARIMA(st_log_diff,order=(2,1,2))
results_arima=model.fit()
plt.plot(st_log_diff)
plt.plot(results_arima.fittedvalues,color='black')
# Out:
# C:\Users\Sanjana\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Sanjana\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Sanjana\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Sanjana\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
import pmdarima as pm

# %%
def arimamodel(timeseries):
    automodel=pm.auto_arima(timeseries,
                             start_p=2,
                             start_q=2,
                              max_p=10,
                              max_q=10,
                              test='adf',
                              seasonal=True,
                              trace=True)
    return automodel

# %%
arimamodel(st_log)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-1163.846, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-1167.424, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-1165.456, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-1165.465, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-1165.525, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-1163.485, Time=0.09 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 0.453 seconds
# ARIMA(order=(0, 1, 0), scoring_args={}, suppress_warnings=True)

# %%
model=ARIMA(st_log_diff,order=(0,1,0))
results_arima=model.fit()
plt.plot(st_log_diff)
plt.plot(results_arima.fittedvalues,color='black')
# Out:
# C:\Users\Sanjana\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Sanjana\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Sanjana\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %% [markdown]
# (p,d,f)=(0,1,0)
# i applied those values to my model again and plotted the fitted model
# original model(blue)nd predicted(black)
